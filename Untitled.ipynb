# %%
import sys, os
sys.path.append(os.path.abspath('.'))


from MTG_card_detector import *

# %%
card_detector = MTGCardDetector()

card_detector.read_and_adjust_reference_images('../../MTG/Card_Images/LEA/')
card_detector.read_and_adjust_test_images('../MTG_alpha_test_images/')
# Out:
# Reading images from ../../MTG/Card_Images/LEA/
# Hashing reference set.
# Reading images from ../MTG_alpha_test_images/

# %%
card_detector.run_recognition(7)
# Out:
# Original image
# Segmentation of art
# 1 cards segmented.
# 2 cards segmented.
# 3 cards segmented.
# 4 cards segmented.
# 5 cards segmented.
# 6 cards segmented.
# 7 cards segmented.
# 8 cards segmented.
# 9 cards segmented.
# 10 cards segmented.
# 11 cards segmented.
# 12 cards segmented.
# 13 cards segmented.
# 14 cards segmented.
# 15 cards segmented.
# 16 cards segmented.
# 17 cards segmented.
# 18 cards segmented.
# 19 cards segmented.
# 20 cards segmented.
# 21 cards segmented.
# 22 cards segmented.
# 23 cards segmented.
# 24 cards segmented.
# 25 cards segmented.
# 26 cards segmented.
# 27 cards segmented.
# 28 cards segmented.
# 29 cards segmented.
# 30 cards segmented.
# 31 cards segmented.
# 32 cards segmented.
# 33 cards segmented.
# 34 cards segmented.
# 35 cards segmented.
# 36 cards segmented.
# 37 cards segmented.
# 38 cards segmented.
# 39 cards segmented.
# 40 cards segmented.
# 41 cards segmented.
# 42 cards segmented.
# 43 cards segmented.
# 44 cards segmented.
# 45 cards segmented.
# 46 cards segmented.
# 47 cards segmented.
# 48 cards segmented.
# 49 cards segmented.
# 50 cards segmented.
# 51 cards segmented.
# 52 cards segmented.
# 53 cards segmented.
# 54 cards segmented.
# 55 cards segmented.
# 56 cards segmented.
# 57 cards segmented.
# 58 cards segmented.
# 59 cards segmented.
# 60 cards segmented.
# 61 cards segmented.
# 62 cards segmented.
# 63 cards segmented.
# 64 cards segmented.
# 65 cards segmented.
# 66 cards segmented.
# 67 cards segmented.
# 68 cards segmented.
# 69 cards segmented.
# 70 cards segmented.
# 71 cards segmented.
# 72 cards segmented.
# 73 cards segmented.
# 74 cards segmented.
# 75 cards segmented.
# 76 cards segmented.
# 77 cards segmented.
# 78 cards segmented.
# Removing 38 duplicates.
# Recognition
# 1 / 40
# 2 / 40
# 3 / 40
# 4 / 40
# 5 / 40
# 6 / 40
# 7 / 40
# 8 / 40
# 9 / 40
# 10 / 40
# 11 / 40
# 12 / 40
# 13 / 40
# 14 / 40
# 15 / 40
# 16 / 40
# 17 / 40
# 18 / 40
# 19 / 40
# 20 / 40
# 21 / 40
# 22 / 40
# 23 / 40
# 24 / 40
# 25 / 40
# 26 / 40
# 27 / 40
# 28 / 40
# 29 / 40
# 30 / 40
# 31 / 40
# 32 / 40
# 33 / 40
# 34 / 40
# 35 / 40
# 36 / 40
# 37 / 40
# 38 / 40
# 39 / 40
# 40 / 40

# %%
card_detector.run_recognition(9)
# Out:
# Original image
# Segmentation of art
# 1 cards segmented.
# 2 cards segmented.
# 3 cards segmented.
# 4 cards segmented.
# 5 cards segmented.
# 6 cards segmented.
# 7 cards segmented.
# 8 cards segmented.
# 9 cards segmented.
# 10 cards segmented.
# 11 cards segmented.
# 12 cards segmented.
# 13 cards segmented.
# 14 cards segmented.
# 15 cards segmented.
# 16 cards segmented.
# 17 cards segmented.
# 18 cards segmented.
# 19 cards segmented.
# 20 cards segmented.
# 21 cards segmented.
# 22 cards segmented.
# 23 cards segmented.
# 24 cards segmented.
# 25 cards segmented.
# 26 cards segmented.
# 27 cards segmented.
# 28 cards segmented.
# 29 cards segmented.
# 30 cards segmented.
# 31 cards segmented.
# 32 cards segmented.
# Removing 4 duplicates.
# Recognition
# 1 / 28
# 2 / 28
# 3 / 28
# 4 / 28
# 5 / 28
# 6 / 28
# 7 / 28
# 8 / 28
# 9 / 28
# 10 / 28
# 11 / 28
# 12 / 28
# 13 / 28
# 14 / 28
# 15 / 28
# 16 / 28
# 17 / 28
# 18 / 28
# 19 / 28
# 20 / 28
# 21 / 28
# 22 / 28
# 23 / 28
# 24 / 28
# 25 / 28
# 26 / 28
# 27 / 28
# 28 / 28

# %%
card_detector.run_recognition(21)
# Out:
# Original image
# Segmentation of art
# 1 cards segmented.
# 2 cards segmented.
# Removing 1 duplicates.
# Recognition
# 1 / 1
